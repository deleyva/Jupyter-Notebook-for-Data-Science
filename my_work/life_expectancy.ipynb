# %% [markdown]
# # Life Expectancy
#
# [data source](https://data.worldbank.org)

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/life_expectancy/API_SP.DYN.LE00.IN_DS2_en_csv_v2_10181296.csv', header=2, index_col=(0, 1, 2, 3))
df.head()
# Out:
#                                                                                     1960  \
# Country Name Country Code Indicator Name                          Indicator Code
# Aruba        ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  65.662
# Afghanistan  AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.292
# Angola       AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  33.251
# Albania      ALB          Life expectancy at birth, total (years) SP.DYN.LE00.IN  62.279
# Andorra      AND          Life expectancy at birth, total (years) SP.DYN.LE00.IN     NaN
#
#                                                                                     1961  \
# Country Name Country Code Indicator Name                          Indicator Code
# Aruba        ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  66.074
# Afghanistan  AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.742
# ...

# %%
life_expectancy = df.groupby(level=0).first().transpose()
life_expectancy.head()
# Out:
# Country Name  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960               32.292   62.279   46.138             NaN      NaN  33.251
# 1961               32.742   63.298   46.596             NaN      NaN  33.573
# 1962               33.185   64.187   47.054             NaN      NaN  33.914
# 1963               33.624   64.911   47.507             NaN      NaN  34.272
# 1964               34.060   65.461   47.956             NaN      NaN  34.645
#
# Country Name  Antigua and Barbuda  Arab World  Argentina  Armenia    ...     \
# 1960                       62.115   46.825065     65.022   65.971    ...
# 1961                       62.555   47.407699     65.141   66.402    ...
# 1962                       62.979   47.988878     65.233   66.837    ...
# 1963                       63.385   48.572229     65.311   67.276    ...
# 1964                       63.774   49.159167     65.388   67.715    ...
#
# Country Name  Uzbekistan  Vanuatu  Venezuela, RB  Vietnam  \
# ...

# %%
life_expectancy_subset = life_expectancy[['China', 'United States', 'Germany', 'Spain']]

# %%
life_expectancy_subset.plot()
